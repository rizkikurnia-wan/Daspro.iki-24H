# %%
data_siswa = {}

def tambah_data():
    try:
        nim = input("Masukkan NIM (11 karakter): ")
        if len(nim) != 11:
            raise ValueError("NIM harus 11 karakter!")

        nama = input("Masukkan Nama (min 3 karakter): ")
        if len(nama) < 3:
            raise ValueError("Nama terlalu pendek!")

        alamat = input("Masukkan Alamat (min 5 karakter): ")
        if len(alamat) < 5:
            raise ValueError("Alamat terlalu pendek!")

        data_siswa[nim] = {'nama': nama, 'alamat': alamat}
        print("Data berhasil ditambahkan.\n")

    except ValueError as ve:
        print("ValueError:", ve)
    except TypeError as te:
        print("TypeError:", te)
    except ZeroDivisionError as zde:
        print("ZeroDivisionError:", zde)
    except Exception as e:
        print("Exception:", e)

def tampilkan_data():
    if not data_siswa:
        print("Data kosong.")
    for nim, info in data_siswa.items():
        print(f"NIM: {nim}, Nama: {info['nama']}, Alamat: {info['alamat']}")

def cari_data():
    cari_nim = input("Masukkan NIM yang dicari: ")
    if cari_nim in data_siswa:
        print("Data ditemukan:", data_siswa[cari_nim])
    else:
        print("Data tidak ditemukan.")


while True:
    print("\nMenu:")
    print("1. Tambah Data Siswa")
    print("2. Tampilkan Data")
    print("3. Exit")
    print("4. Cari Data")

    pilihan = input("Pilih menu (1-4): ")
    if pilihan == '1':
        tambah_data()
    elif pilihan == '2':
        tampilkan_data()
    elif pilihan == '3':
        print("Keluar dari program.")
        break
    elif pilihan == '4':
        cari_data()
    else:
        print("Pilihan tidak valid.")
# Out:
# Menu:
# 1. Tambah Data Siswa
# 2. Tampilkan Data
# 3. Exit
# 4. Cari Data
# Pilih menu (1-4): 1
# Masukkan NIM (11 karakter): 20240040113
# Masukkan Nama (min 3 karakter): 2
# ValueError: Nama terlalu pendek!
#
# Menu:
# 1. Tambah Data Siswa
# 2. Tampilkan Data
# 3. Exit
# 4. Cari Data
# Pilih menu (1-4): 1
# Masukkan NIM (11 karakter): 20240040113
# Masukkan Nama (min 3 karakter): iki
# Masukkan Alamat (min 5 karakter): caringin
# Data berhasil ditambahkan.
#
#
# Menu:
# 1. Tambah Data Siswa
# 2. Tampilkan Data
# 3. Exit
# 4. Cari Data
# Pilih menu (1-4): 2
# NIM: 20240040113, Nama: iki, Alamat: caringin
#
# Menu:
# 1. Tambah Data Siswa
# 2. Tampilkan Data
# 3. Exit
# 4. Cari Data
# Pilih menu (1-4): 3
# Keluar dari program.
